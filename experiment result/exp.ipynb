# %%
# %pylab inline
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 12})

iterations = [5, 10, 15, 25, 50, 100]
data={
    'factor_with_y': [0.90647392345648958, 0.87860970659724458, 0.87538288964632904, 0.87871370981797203, 0.88814789789925264, 0.91439048378141463],
    'factor_without_y': [0.90173184234791948, 0.87767627875669552, 0.87445678431240015, 0.8790071074845115, 0.89273694359540434, 0.89143607988068874],
    'neighbor_with_c': [0.89155133903802553, 0.86848193585590938, 0.8643909388754214, 0.86452308214170925, 0.86353846395035161, 0.86016006496024955],
    'neighbor_without_c': [0.90099938533908175, 0.87593745004632717, 0.87080879062314009, 0.87230463042325168, 0.879699540241628, 0.88662072217269539],
    'Integrated':  [0.89622306324786227, 0.86878380117076481, 0.86240973069252025, 0.86290842278496283, 0.86281330057751959, 0.86084494420362268]
}

plt.figure()
for name in ['factor_with_y', 'factor_without_y']:
    plt.plot(iterations, data[name], '-o', label=name, linewidth=2.5)
plt.legend(loc='best')

plt.figure()
for name in ['neighbor_with_c', 'neighbor_without_c']:
    plt.plot(iterations, data[name], '-o', label=name, linewidth=2.5)
plt.legend(loc='best')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.4/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
iterations = [5, 10, 15, 25, 50, 100]
data={
'Bias_Training':  [0.67516407428668801, 0.63303900320800666, 0.61415387874552319, 0.59677770232301763, 0.58383716176486666, 0.5790786898045065],
'Bias_Testing':  [0.90252341558002069, 0.87804352888419201, 0.87449905606789191, 0.87936163192542693, 0.89193660140760656, 0.89807255115300644],
'Neighbor_Training':  [0.65204373027289686, 0.59394339761162551, 0.55982412874776533, 0.51374943589657474, 0.43745964936955345, 0.33397922074815789],
'Neighbor_Testing':  [0.90084395598104638, 0.87577055784564384, 0.87083277588541186, 0.87292157681576399, 0.88153267801632507, 0.88817189345173031],
'Factor_Training':  [0.67493762284911618, 0.63278319829181073, 0.61384201967228857, 0.596290032573914, 0.58179600663361519, 0.52828461671950289],
'Factor_Testing':  [0.90248631419621794, 0.87801691758809541, 0.87451620532591523, 0.8794573605160515, 0.89181270540145041, 0.89688439369582396] 
}

f, axarr = plt.subplots(2, sharex=True, figsize=(8, 8))
for name in ['Bias_Training', 'Neighbor_Training',  'Factor_Training'] :
    axarr[0].plot(iterations, data[name], '-o', label=name, linewidth=2.5)
# axarr[0].legend(bbox_to_anchor=(1, 1),loc='upper right', ncol=1)
axarr[0].legend(loc='best')
# axarr[0].set_ylim([0.3, 2.9])


for name in ['Bias_Testing', 'Neighbor_Testing', 'Factor_Testing']:
    axarr[1].plot(iterations, data[name], '-o', label=name, linewidth=2.5)
axarr[1].legend(loc='best')
# axarr[1].legend(bbox_to_anchor=(1.48, 1),loc='upper right', ncol=1)
plt.xlabel('Iteration',fontsize=16)
plt.savefig('/home/mingo/courses/ml/project/final/graphs/iteration_train_test.png')

# %%
k =  [1, 5, 10, 25, 50, 100]
data={
'neighbor_without_c':  [0.731895533151, 0.723303364058, 0.723341450899, 0.719925238362, 0.725261122904, 0.726489341554],
'neighbor_with_c':  [0.732882662045, 0.735307752146, 0.734741351223, 0.729449725289, 0.72753958159, 0.728527103589],
'factor_with_y': [0.739056192043, 0.731499144142, 0.730675789754, 0.730477352689, 0.730731901718, 0.730638925935],
'factor_without_y': [0.746849253393, 0.730224244618, 0.731045602091, 0.730208810462, 0.730565125735, 0.730619458973]
}
f, axarr = plt.subplots(2, sharex=True, figsize=(8, 8))
for name in ['neighbor_with_c', 'neighbor_without_c'] :
    axarr[0].plot(k, data[name], '-o', label=name, linewidth=2.5)
# axarr[0].legend(bbox_to_anchor=(1.48, 1),loc='upper right', ncol=1)
axarr[0].legend(loc='best')
# axarr[0].set_ylim([0.3, 2.9])


for name in ['factor_with_y', 'factor_without_y'] :
    axarr[1].plot(k, data[name], '-o', label=name, linewidth=2.5)
# axarr[1].legend(bbox_to_anchor=(1.43, 1),loc='upper right', ncol=1)
axarr[1].legend(loc='best')
plt.xlabel('k/d',fontsize=16)
plt.savefig('/home/mingo/courses/ml/project/final/graphs/varykd.png')

# %%
iterations = [5, 10, 15, 25, 50, 100]
data={
'Bias':  [0.724301375678, 0.722496732765, 0.730622354947, 0.746721356782, 0.766707469337,  0.773208670013],
'Neighbor':  [0.721870132622, 0.716091086584,  0.719925238362, 0.728596346803, 0.73617401794, 0.73440179337],
'Factor': [0.723897713698, 0.722510455022, 0.73073430457, 0.746771324955, 0.767159199915, 0.771123034107],
'Integrated':  [0.721445757061, 0.716086378582, 0.720029589166, 0.728702526545, 0.73673780014, 0.734159028154]
}
plt.figure(figsize=(6, 4))
for name in ['Bias', 'Neighbor', 'Factor', 'Integrated'] :
    plt.plot(iterations, data[name], '-o', label=name, linewidth=2.5)
# axarr[0].legend(bbox_to_anchor=(1.48, 1),loc='upper right', ncol=1)
plt.legend(loc='upper left')
plt.xlabel('iteration',fontsize=16)
plt.savefig('/home/mingo/courses/ml/project/final/graphs/compare.png')

# %%
iterations = [5, 10, 15, 25, 50, 100]
data={
'User_based':  [0.677875725728, 0.637886305216, 0.621277514161, 0.610718621146, 0.614367982888, 0.644454269877],
'Item_based':  [0.683636193012, 0.643406800881, 0.626809501608, 0.617196634253, 0.623796956975, 0.643615772092 ],
}
plt.figure(figsize=(6, 4))
for name in ['User_based', 'Item_based'] :
    plt.plot(iterations, data[name], '-o', label=name, linewidth=2.5)
# axarr[0].legend(bbox_to_anchor=(1.48, 1),loc='upper right', ncol=1)
plt.legend(loc='upper left')
plt.xlabel('iteration',fontsize=16)
plt.savefig('/home/mingo/courses/ml/project/final/graphs/user_oriented.png')

# %%
iterations = [5, 10, 15, 25, 50, 100]
data={
'User_based':  [0.554068668952, 0.542838022466, 0.542838022466, 0.535741262854, 0.533695197, 0.541790782479],
'Item_based':  [0.550076157256, 0.542997895603, 0.543561520867, 0.556514453063, 0.602364317164, 0.697333077006],
}
plt.figure(figsize=(6, 4))
for name in ['User_based', 'Item_based'] :
    plt.plot(iterations, data[name], '-o', label=name, linewidth=2.5)
# axarr[0].legend(bbox_to_anchor=(1.48, 1),loc='upper right', ncol=1)
plt.legend(loc='upper left')
plt.xlabel('iteration',fontsize=16)
plt.savefig('/home/mingo/courses/ml/project/final/graphs/item_oriented.png')
